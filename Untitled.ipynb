# %%
import pylast

API_KEY = '3c4a9e794650d6c07138508938f3b7b8'

lastfm = pylast.LastFMNetwork(
    api_key=API_KEY,
)

print(lastfm.get_album_by_mbid("7809de33-4f1c-4d74-8e69-be4df9d24247"))
# Out:
# Dire Straits - Love Over Gold
